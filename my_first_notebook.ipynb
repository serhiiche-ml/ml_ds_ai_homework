# %% [markdown]
# ### 1. My first notebook

# %%
print("Hello world!")
# Out:
# Hello world!

# %%
import matplotlib.pyplot as plt

# %% [markdown]
# ### 1.1 Simple math

# %%
1 + 100 / 4
# Out:
# 26.0

# %%
1 + 2
2 + 4
# Out:
# 6

# %%
import numpy as np

# %%
plt.plot(np.sin(range(15)))
plt.show()
